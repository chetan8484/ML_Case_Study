# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing Dataset
df= pd.read_csv('Leads.csv')

# %%
#Creating copy of dataset
df_original = df.copy()

# %%
#Showing Top 5 Records
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
#Checking No of Rows and Columns
df.shape
# Out:
# (9240, 37)

# %%
#Displaying Columns
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
#Replacing 'Select' with Null values,Records with the 'Select' values has equal proportion of 0 and 1 so it is as good null.
df.replace('Select',np.nan , inplace = True)

# %%
# Displaying Null values using 'For loop' for each column.
for i in df.columns:
    print('->',i)
    print(df[i].isnull().sum())
    print("##########################################")
# Out:
# -> Prospect ID
# 0
# ##########################################
# -> Lead Number
# 0
# ##########################################
# -> Lead Origin
# 0
# ##########################################
# -> Lead Source
# 36
# ##########################################
# -> Do Not Email
# 0
# ##########################################
# -> Do Not Call
# 0
# ##########################################
# -> Converted
# 0
# ##########################################
# -> TotalVisits
# 137
# ##########################################
# -> Total Time Spent on Website
# 0
# ##########################################
# -> Page Views Per Visit
# 137
# ##########################################
# -> Last Activity
# 103
# ##########################################
# -> Country
# 2461
# ##########################################
# -> Specialization
# 3380
# ##########################################
# -> How did you hear about X Education
# 7250
# ##########################################
# ...

# %%
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
# Checking Datatypes and Non Null values of all the Columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %% [markdown]
# # Checking All Unique Values:

# %%
df['Receive More Updates About Our Courses'].nunique()
# Out:
# 1

# %%
df['Update me on Supply Chain Content'].nunique()
# Out:
# 1

# %%
df['I agree to pay the amount through cheque'].nunique()
# Out:
# 1

# %%
df['Get updates on DM Content'].nunique()
# Out:
# 1

# %%
df['Last Notable Activity'].nunique()
# Out:
# 16

# %%
df['Last Notable Activity'].value_counts()
# Out:
# Modified                        3407
# Email Opened                    2827
# SMS Sent                        2172
# Page Visited on Website          318
# Olark Chat Conversation          183
# Email Link Clicked               173
# Email Bounced                     60
# Unsubscribed                      47
# Unreachable                       32
# Had a Phone Conversation          14
# Email Marked Spam                  2
# Approached upfront                 1
# Resubscribed to emails             1
# View in browser link Clicked       1
# Form Submitted on Website          1
# Email Received                     1
# Name: Last Notable Activity, dtype: int64

# %%
df['Last Activity'].value_counts()
# Out:
# Email Opened                    3437
# SMS Sent                        2745
# Olark Chat Conversation          973
# Page Visited on Website          640
# Converted to Lead                428
# Email Bounced                    326
# Email Link Clicked               267
# Form Submitted on Website        116
# Unreachable                       93
# Unsubscribed                      61
# Had a Phone Conversation          30
# Approached upfront                 9
# View in browser link Clicked       6
# Email Received                     2
# Email Marked Spam                  2
# Visited Booth in Tradeshow         1
# Resubscribed to emails             1
# Name: Last Activity, dtype: int64

# %%
df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
#Droping Unnecessay Columns according to our Analysis.
df.drop(['Prospect ID','Lead Number','Search', 'Magazine', 'Newspaper Article', 'X Education Forums',
       'Newspaper', 'Digital Advertisement', 'Through Recommendations',
       'Receive More Updates About Our Courses',
       'Update me on Supply Chain Content', 'Get updates on DM Content',
       'I agree to pay the amount through cheque',
       'A free copy of Mastering The Interview','Last Notable Activity'] , inplace = True , axis = 1)

# %%
# Remaining Coluns 
df.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
#        'Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Last Activity', 'Country', 'Specialization',
#        'How did you hear about X Education', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Tags', 'Lead Quality',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score'],
#       dtype='object')

# %%
# Counting No of Null Values.
df.isna().sum()
# Out:
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   3380
# How did you hear about X Education               7250
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Tags                                             3353
# Lead Quality                                     4767
# Lead Profile                                     6855
# ...

# %%
#Displaying Correlation between all numeric Columns.
sns.heatmap(df.corr() ,annot = True)
# Out:
# <AxesSubplot:>

# %%
# Finding the Outliers
#we plot box-plot for finding outliers but as we dont have large no of outliers so there is no need to deal with it.
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Displaying Data Distribution of Each column.

# %%
import seaborn as sns
sns.pairplot(df)

#To understand variation between columns we have draw a pair plot

# %%
#this is lead profile graph and here
#Displaying how the data in lead column is distributed.
plt.xticks(rotation=90)
sns.countplot(df_original['Lead Profile'] , hue=df.Converted)
# Out:
# C:\Users\Aakash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Lead Profile', ylabel='count'>

# %% [raw]
# The above Graph showcase lead profile counts with respect to their lead Conversion, Potential leads has a high lead conversion rate.

# %%
sns.countplot(df_original['Lead Quality'] , hue=df.Converted)
# Out:
# C:\Users\Aakash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Lead Quality', ylabel='count'>

# %% [raw]
# The above Graph showcase lead Quality counts with respect to their lead Conversion, High in Relevance, Might be has a high lead conversion rate.

# %%
#Checking Columns
df.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
#        'Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Last Activity', 'Country', 'Specialization',
#        'How did you hear about X Education', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Tags', 'Lead Quality',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score'],
#       dtype='object')

# %%
plt.subplot(2,2,1)
sns.countplot(data=df_original,x='Do Not Email', hue='Converted')
plt.show()

# %% [raw]
# The above Graph showcase  "Do Not Email" counts with respect to their lead Conversion, We have High amount of "No" compared to "yes" which means more No. of people get contacted through Emails.

# %%
plt.subplot(2,2,2)
sns.countplot(data=df_original,x='Do Not Call', hue='Converted')
plt.show()

# %% [raw]
# The above Graph showcase  "Do Not Call" counts with respect to their lead Conversion, We have High amount of "No" compared to "yes" which means more No. of people get contacted through Calls.

# %%
plt.xticks(rotation=90)
sns.countplot(data=df_original,x='Tags',hue='Converted')
# Out:
# <AxesSubplot:xlabel='Tags', ylabel='count'>

# %% [markdown]
# The above Graph showcase  "Tags" counts with respect to their lead Conversion,We have  High amount data for 'Ringing' , 'Will revert after reading the email'.

# %%
plt.xticks(rotation=45)
sns.countplot(data=df_original,x='What is your current occupation',hue='Converted')
# Out:
# <AxesSubplot:xlabel='What is your current occupation', ylabel='count'>

# %% [raw]
# The above Graph showcase  "What is your Current Occupation" counts with respect to their lead Conversion, We have High amount of Unemployed clients and working professional .

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sns.countplot(data=df_original,x='TotalVisits', hue='Converted')
plt.show()

# %% [raw]
# The above Graph showcase  "Total Visit" counts with respect to their lead Conversion, we have high amount of people who only visit site for 0-4 times.

# %%
plt.figure(figsize=(10,5))
s1 = sns.countplot(data=df_original,x='Lead Source', hue='Converted')
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)

plt.show()

# %% [raw]
# The above Graph showcase  "Lead Source" counts with respect to their lead Conversion, it shows the medium through which people got to know about this Educational site.

# %%
#Finding total null values in Lead Quality Coumn.
df['Lead Quality'].isna().sum()
# Out:
# 4767

# %%
# Dropping Columns using for loop where the null values are greater than 1000
for i in df.columns:
    
    if(df[i].isnull().sum()) > 1000 and i not in ['Lead Quality','What is your current occupation','City']:
        print('Dropping: ',i)
        df.drop( [i],axis = 1,inplace = True )
# Out:
# Dropping:  Country
# Dropping:  Specialization
# Dropping:  How did you hear about X Education
# Dropping:  What matters most to you in choosing a course
# Dropping:  Tags
# Dropping:  Lead Profile
# Dropping:  Asymmetrique Activity Index
# Dropping:  Asymmetrique Profile Index
# Dropping:  Asymmetrique Activity Score
# Dropping:  Asymmetrique Profile Score

# %%
# Checking Value counts in Lead Source and Lead Origin.
df['Lead Origin'].value_counts()
# Out:
# Landing Page Submission    4886
# API                        3580
# Lead Add Form               718
# Lead Import                  55
# Quick Add Form                1
# Name: Lead Origin, dtype: int64

# %%
df['Lead Source'].value_counts()
# Out:
# Google               2868
# Direct Traffic       2543
# Olark Chat           1755
# Organic Search       1154
# Reference             534
# Welingak Website      142
# Referral Sites        125
# Facebook               55
# bing                    6
# google                  5
# Click2call              4
# Press_Release           2
# Social Media            2
# Live Chat               2
# youtubechannel          1
# testone                 1
# Pay per Click Ads       1
# welearnblog_Home        1
# WeLearn                 1
# blog                    1
# NC_EDM                  1
# Name: Lead Source, dtype: int64

# %%
# Droped "Lead Source" and "Last Activity" as we found data in particular Columsn are 
#Irrelevant as this data Could be Useful Marketing Purpose not in analysing Leads.
df.drop(['Lead Source' , 'Last Activity'] , axis = 1 , inplace = True)

# %%
df.columns
# Out:
# Index(['Lead Origin', 'Do Not Email', 'Do Not Call', 'Converted',
#        'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit',
#        'What is your current occupation', 'Lead Quality', 'City'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Lead Origin                           0
# Do Not Email                          0
# Do Not Call                           0
# Converted                             0
# TotalVisits                         137
# Total Time Spent on Website           0
# Page Views Per Visit                137
# What is your current occupation    2690
# Lead Quality                       4767
# City                               3669
# dtype: int64

# %% [markdown]
# # Replacing null values with 'Mean-Method' as both columns has Numeric Values.

# %%
df['TotalVisits'].replace(np.nan , df['TotalVisits'].mean() , inplace = True)

# %%
df['Page Views Per Visit'].replace(np.nan , df['Page Views Per Visit'].mean() , inplace = True)

# %%
df.isna().sum()
# Out:
# Lead Origin                           0
# Do Not Email                          0
# Do Not Call                           0
# Converted                             0
# TotalVisits                           0
# Total Time Spent on Website           0
# Page Views Per Visit                  0
# What is your current occupation    2690
# Lead Quality                       4767
# City                               3669
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Lead Origin                      9240 non-null   object
#  1   Do Not Email                     9240 non-null   object
#  2   Do Not Call                      9240 non-null   object
#  3   Converted                        9240 non-null   int64
#  4   TotalVisits                      9240 non-null   float64
#  5   Total Time Spent on Website      9240 non-null   int64
#  6   Page Views Per Visit             9240 non-null   float64
#  7   What is your current occupation  6550 non-null   object
#  8   Lead Quality                     4473 non-null   object
#  9   City                             5571 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 722.0+ KB

# %%
# Do Not Call has a biased data as it has more number of No as compared to Yes so dropping the column will be a better idea
df['Do Not Call'].value_counts()
# Out:
# No     9238
# Yes       2
# Name: Do Not Call, dtype: int64

# %%
# Since the number of Yes is 2 and Number of No is 9238, it can lead to high bias in our data
df.drop(['Do Not Call'], axis = 1 , inplace = True)

# %%
# These are the value counts for Do Not Email Columns
df['Do Not Email'].value_counts()
# Out:
# No     8506
# Yes     734
# Name: Do Not Email, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Lead Origin                      9240 non-null   object
#  1   Do Not Email                     9240 non-null   object
#  2   Converted                        9240 non-null   int64
#  3   TotalVisits                      9240 non-null   float64
#  4   Total Time Spent on Website      9240 non-null   int64
#  5   Page Views Per Visit             9240 non-null   float64
#  6   What is your current occupation  6550 non-null   object
#  7   Lead Quality                     4473 non-null   object
#  8   City                             5571 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 649.8+ KB

# %%
df.columns
# Out:
# Index(['Lead Origin', 'Do Not Email', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit',
#        'What is your current occupation', 'Lead Quality', 'City'],
#       dtype='object')

# %%
# To convert categorical data to numerical data and all the null values are ignored. 
df = pd.get_dummies(df)

# %%
df.columns
# Out:
# Index(['Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Lead Origin_API',
#        'Lead Origin_Landing Page Submission', 'Lead Origin_Lead Add Form',
#        'Lead Origin_Lead Import', 'Lead Origin_Quick Add Form',
#        'Do Not Email_No', 'Do Not Email_Yes',
#        'What is your current occupation_Businessman',
#        'What is your current occupation_Housewife',
#        'What is your current occupation_Other',
#        'What is your current occupation_Student',
#        'What is your current occupation_Unemployed',
#        'What is your current occupation_Working Professional',
#        'Lead Quality_High in Relevance', 'Lead Quality_Low in Relevance',
#        'Lead Quality_Might be', 'Lead Quality_Not Sure', 'Lead Quality_Worst',
#        'City_Mumbai', 'City_Other Cities', 'City_Other Cities of Maharashtra',
#        'City_Other Metro Cities', 'City_Thane & Outskirts',
#        'City_Tier II Cities'],
#       dtype='object')

# %%
df
# Out:
#       Converted  TotalVisits  Total Time Spent on Website  \
# 0             0          0.0                            0
# 1             0          5.0                          674
# 2             1          2.0                         1532
# 3             0          1.0                          305
# 4             1          2.0                         1428
# ...         ...          ...                          ...
# 9235          1          8.0                         1845
# 9236          0          2.0                          238
# 9237          0          2.0                          199
# 9238          1          3.0                          499
# 9239          1          6.0                         1279
#
#       Page Views Per Visit  Lead Origin_API  \
# 0                     0.00                1
# 1                     2.50                1
# 2                     2.00                0
# 3                     1.00                0
# ...

# %%
df.describe()
# Out:
#          Converted  TotalVisits  Total Time Spent on Website  \
# count  9240.000000  9240.000000                  9240.000000
# mean      0.385390     3.445238                   487.698268
# std       0.486714     4.818723                   548.021466
# min       0.000000     0.000000                     0.000000
# 25%       0.000000     1.000000                    12.000000
# 50%       0.000000     3.000000                   248.000000
# 75%       1.000000     5.000000                   936.000000
# max       1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Lead Origin_API  \
# count           9240.000000      9240.000000
# mean               2.362820         0.387446
# std                2.145333         0.487193
# min                0.000000         0.000000
# 25%                1.000000         0.000000
# 50%                2.000000         0.000000
# 75%                3.000000         1.000000
# max               55.000000         1.000000
#
# ...

# %%
# Categorizing the data as independent and dependent columns 

x = df.drop(['Converted'] , axis=1).values
y = df['Converted'].values

# %%
# Standardizing the data using StandardScaler Method

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)

# %%
df.head()
# Out:
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
#
#    Lead Origin_API  Lead Origin_Landing Page Submission  \
# 0                1                                    0
# 1                1                                    0
# 2                0                                    1
# 3                0                                    1
# 4                0                                    1
#
#    Lead Origin_Lead Add Form  Lead Origin_Lead Import  \
# 0                          0                        0
# ...

# %%
# Spliting the data into train and test Data.
from sklearn.model_selection import train_test_split

x_train , x_test, y_train , y_test = train_test_split(x,y , test_size=0.2,random_state = 0)

# %% [markdown]
# # Creating Model:Logistic Regression.

# %%
# Creating a model
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict_proba(x_test)

# %%
y_pred
# Out:
# array([[0.42719237, 0.57280763],
#        [0.00694808, 0.99305192],
#        [0.77217591, 0.22782409],
#        ...,
#        [0.04793412, 0.95206588],
#        [0.83495467, 0.16504533],
#        [0.1925085 , 0.8074915 ]])

# %%
lr.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
pred_prob_list = []
for i in lr.predict_proba(x):
    pred_prob_list.append(round(i[1]*100,2))
    
pred_prob_list
# Out:
# [61.92,
#  38.65,
#  92.19,
#  16.68,
#  90.34,
#  9.18,
#  94.37,
#  9.18,
#  4.72,
#  7.71,
#  82.71,
#  52.28,
#  87.66,
#  9.26,
#  9.52,
#  81.11,
#  9.18,
#  80.02,
#  71.03,
#  1.27,
#  14.98,
#  2.48,
#  85.71,
#  26.14,
#  97.84,
#  39.52,
#  83.48,
#  96.12,
#  13.61,
#  84.92,
#  83.36,
#  16.74,
#  67.79,
#  9.41,
#  41.55,
#  81.81,
#  90.93,
#  90.71,
#  21.78,
#  77.32,
#  24.29,
#  2.47,
#  17.32,
#  6.09,
#  16.63,
#  53.5,
#  89.94,
#  9.18,
#  5.61,
#  9.18,
#  56.85,
#  11.51,
#  59.0,
#  13.74,
#  9.59,
#  16.29,
#  45.53,
#  94.78,
#  14.75,
#  18.42,
#  17.19,
#  18.45,
#  98.54,
#  9.18,
#  97.09,
#  52.42,
#  96.5,
#  66.19,
#  61.92,
#  18.45,
#  12.03,
#  13.61,
#  4.25,
#  14.49,
#  9.51,
#  45.05,
#  92.81,
#  94.95,
#  29.8,
#  99.64,
#  24.4,
#  83.22,
#  85.89,
#  9.18,
#  82.17,
#  24.06,
#  15.49,
#  6.1,
#  99.78,
#  49.92,
#  20.36,
#  61.56,
#  5.4,
#  17.91,
#  20.26,
#  12.28,
#  23.9,
#  18.45,
#  96.6,
#  97.67,
#  76.35,
#  18.45,
#  18.67,
# ...

# %%
d1 = {'Lead Number' : df_original['Lead Number'].tolist(), 'Leads Score' : pred_prob_list}

pd.DataFrame(d1)

#a lead score between 0 and 100 to each of the leads which can be used by the company to target potential leads.
#A higher score would mean that the lead is hot, i.e. is most likely to convert whereas a lower score would mean that 
#the lead is cold and will mostly not get converted.
# Out:
#       Lead Number  Leads Score
# 0          660737        61.92
# 1          660728        38.65
# 2          660727        92.19
# 3          660719        16.68
# 4          660681        90.34
# ...           ...          ...
# 9235       579564        96.93
# 9236       579546        50.48
# 9237       579545         4.93
# 9238       579538        12.07
# 9239       579533        85.02
#
# [9240 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,lr.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87      1125
#            1       0.81      0.75      0.78       723
#
#     accuracy                           0.83      1848
#    macro avg       0.83      0.82      0.82      1848
# weighted avg       0.83      0.83      0.83      1848

# %%
# Displaying True-Postive and True-Negative with use of Confusion Matrix.
from sklearn.metrics import confusion_matrix , accuracy_score

cm = confusion_matrix(lr.predict(x_test) , y_test)

# %%
cm
# Out:
# array([[1002,  184],
#        [ 123,  539]], dtype=int64)

# %%
accuracy_score(lr.predict(x_test) , y_test)
# Out:
# 0.8338744588744589

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
